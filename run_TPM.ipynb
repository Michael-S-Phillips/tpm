# %%
from TPM import TPM
# %matplotlib inline

# %%
h, mh, hh, x, l, lon, dt, t, Tl, Tl_all, Tsl, tti, dw, Tl_max, tanom = TPM(25, 0, 'warm', 'regolith', 5e-3, 2)

# %%
import matplotlib.pyplot as plt
plt.plot(l, Tsl.flatten())
plt.show()

# %%
l
# Out:
# array([0.25])

# %%
a = -2000**0,25

# %%
b = 2**0.25

# %%
a[0]*a[1]
# Out:
# -25
