# %%
from TPM import TPM
# %matplotlib inline

# %%
h, mh, hh, x, l, lon, dt, t, Tl, Tl_all, Tsl, tti, dw, Tl_max, tanom = TPM(25, 0, 'warm', 'regolith', 5e-3, 2)

# %%
import matplotlib.pyplot as plt
plt.plot(l, Tsl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/phillipsm/Documents/Software/mercury_tpm/run_TPM.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/phillipsm/Documents/Software/mercury_tpm/run_TPM.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/Users/phillipsm/Documents/Software/mercury_tpm/run_TPM.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(Tsl)
#
# NameError: name 'Tsl' is not defined

# %%
4222.6/24
# Out:
# 175.9416666666667

# %%
a = -2000**0,25

# %%
b = 2**0.25

# %%
a[0]*a[1]
# Out:
# -25
